# %%
import pandas as pd
import numpy as np
from pathlib import Path
import warnings

warnings.filterwarnings("ignore")

# %%
DATA_DIR = Path("../data/mimic")

print("Data directory:", DATA_DIR.resolve())
print("Exists:", DATA_DIR.exists())
# Out:
# Data directory: C:\Users\Dell\data\mimic
# Exists: False
